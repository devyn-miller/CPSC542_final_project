# %%
import os

# Define the directory to start the traversal
project_directory = '/Users/devynmiller/CPSC542_final_project'

# Define the output file where the code contents will be written
output_file_path = 'code_contents.txt'

# Open the output file in write mode
with open(output_file_path, 'w') as output_file:
    # Walk through the project directory
    for root, dirs, files in os.walk(project_directory):
        for file_name in files:
            # Construct the full file path
            file_path = os.path.join(root, file_name)
            # Open and read the contents of the file
            with open(file_path, 'r') as file:
                try:
                    # Read the contents of the file
                    contents = file.read()
                    # Write the contents to the output file
                    output_file.write(contents)
                    # Optionally, write a separator between files' contents
                    output_file.write('\n\n')
                except Exception as e:
                    # Handle exceptions (e.g., if the file cannot be read)
                    print(f"Could not read file {file_path}: {e}")

print(f"Code contents have been written to {output_file_path}")
# Out:
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/index: 'utf-8' codec can't decode byte 0xc3 in position 33: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/0c/925e8dff3a07f1b0b183e4ca56180d6c15c170: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/50/a2334f2e78b8df81cc06f28602545b054d9ba0: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/68/9e6a1a96cf950307b20078e6dd256d12e35675: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/6f/f4cc052008d32cde7f53d6de6ca10016ebf7b4: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/6f/b9b1c7a6ee728c1f38ba9303996741c7aa9bfa: 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/69/25a1cbb37893f8692688f650425a6ef8566b72: 'utf-8' codec can't decode byte 0xae in position 5: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/3c/fbd3cd38546f011bf1203156c604409715ad1b: 'utf-8' codec can't decode byte 0xcd in position 2: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/56/0cb45945a82232111851c44c1f65702c91b623: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/51/0a3850da7a8182b3c0e84ab3d9f050e4154559: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/58/78ae17771f8db81332e9c9a2ecc45c3f0c3de0: 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/93/e8d471761b5ec561a09abdc15339516b917186: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/34/7caf8b87252bbd2984ba2f0170da9a27dd7371: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/9c/eba471e3347eea368dab92a1063b64b050e1b6: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/a3/e40c91df70802d0af55b6a6f38ccd68e64934b: 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/b5/a51e1d680a6d0dec28e7ac5b5d0c7e23eb054b: 'utf-8' codec can't decode byte 0xdb in position 4: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/b2/997d2a4cf1a53dfb2bb5773a949709a54b33ae: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/b2/432deb2fc0b13383853d2b807b845eb99e67eb: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/ac/3aebc02984a1a1ebd027115b87a853d64d3e47: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/df/dc0438e0fc4586b884d86ac0a372d898981ba1: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/e2/791b4f45e0bd7629874da4b5bf0c809b974a1d: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/f4/4e5599926e1eeaea97c8c40579d8f47db7dddc: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/f3/56503cc0ee4bba0cdf400a76595af94d340899: 'utf-8' codec can't decode byte 0xbd in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/c9/b6e6539ccb7c6aa5242b8feb023dcb88212a7d: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/ed/832f2f5b791ee73575c4f4d263506b2c2d65bc: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/c6/08b7a7876ed038a6d97840564dce204c32c199: 'utf-8' codec can't decode byte 0xce in position 18: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/c6/36e1a4221e9e16c61b49050df51194140b76b9: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/pack/pack-b797d2de2897be5b061bcf30a088957863fd3635.pack: 'utf-8' codec can't decode byte 0x9b in position 12: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/pack/pack-b797d2de2897be5b061bcf30a088957863fd3635.rev: 'utf-8' codec can't decode byte 0xb7 in position 360: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/pack/pack-b797d2de2897be5b061bcf30a088957863fd3635.idx: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/89/de462cae6a544eb601c5e411f2e48db49f3fb8: 'utf-8' codec can't decode byte 0xc1 in position 4: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/87/35fa1eb9f3895c700e925cc0f07af663bab774: 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/74/23e69cb738bc73c728f28b16dcbe952813e470: 'utf-8' codec can't decode byte 0xcd in position 2: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/17/a0c81861597872936eb5b1c231843dff455183: 'utf-8' codec can't decode byte 0xbd in position 4: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/8a/0fddf0539966d42683f8350de8d3ca34ac91fa: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/8a/7249518966204ba63bd08eea66f81d9f5d4e58: 'utf-8' codec can't decode byte 0xc1 in position 4: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/86/fcdfb0389fcf6a9222abe9652d3b167082de14: 'utf-8' codec can't decode byte 0xc1 in position 4: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/43/8d99eb27d46ec56d51c070f2778bd7e11aec8f: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/6b/cc1e4e8877e01bf6baa8d403c6856b6868f2ef: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/5c/599b5426edebde35a27f0318d70e4f24fdd4b5: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/09/f7a0a29e3deef9d01e2dc534a26e213fbc3fe8: 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/96/903059606c131f49b983ea24397d1bdab961f5: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/5b/89dc55719062a76cac4cd7133c220552936bd4: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/01/b2c232bd5748dbe20eb3fc11fa4c8a56f0e231: 'utf-8' codec can't decode byte 0xdb in position 4: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/0f/25676dee0132c8f2f5b530a3d8c321dae35d1d: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/64/c80cea29008d187677c39e1c45b7ace5240e4d: 'utf-8' codec can't decode byte 0xc4 in position 6: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/bf/8aad646ecf49f58334635d21789df5ed7f4b9a: 'utf-8' codec can't decode byte 0xb4 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/d3/271a049d10138bd11e9f7951cdb81f536456de: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/a9/8b122bee49aba76a9d7a27c31b4612d5aa5a05: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/db/a3e8d52b24df91258d48ffb108a71797bf4c33: 'utf-8' codec can't decode byte 0x9b in position 6: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/de/c779754c84a2f6ac7accc2edf466701bafe89f: 'utf-8' codec can't decode byte 0xb1 in position 9: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/b9/8bcb2cea81a3518be478037e6998166dfce000: 'utf-8' codec can't decode byte 0xb5 in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/ff/38f7861560ddd898165b431d9c7d94df7799a2: 'utf-8' codec can't decode byte 0xb1 in position 4: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/c5/a8a2236af75294467200ddee6305ac345eb32b: 'utf-8' codec can't decode byte 0xc4 in position 6: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/e9/a79af05890f056314765d1e17849e4d2d8c4cf: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/e7/0ae1f38ac740b8b6455e0c45c77dbb9778c350: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/2d/c49690e96f968b08007f292f32027d160e340c: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/1e/1f8d718e174cb125d5625bfaacb48c50cf32e8: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/23/b48ecb9586c4068057c75c8d33b176da95a885: 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/1d/715c9b18eb2ecc1ad92cf15859a8ae1004d4a9: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/49/df8ac89076a30965716ea4be07d16f94544793: 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/2e/1943e7b23807f4987f0b8652946af594fef768: 'utf-8' codec can't decode byte 0x9e in position 9: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/2b/ffb9cc546b9ab75abe6b795b0a49fa3ab2fab6: 'utf-8' codec can't decode byte 0xb2 in position 8: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/8b/0b96d9d8b29b40be1c9871edb75d2846801b13: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/.git/objects/22/d7a2baf3ecec14d303860e63019225ada07c23: 'utf-8' codec can't decode byte 0x88 in position 18: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/src/objects/__pycache__/data.cpython-311.pyc: 'utf-8' codec can't decode byte 0xa7 in position 0: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/src/objects/__pycache__/stack.cpython-311.pyc: 'utf-8' codec can't decode byte 0xa7 in position 0: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/src/objects/__pycache__/__init__.cpython-311.pyc: 'utf-8' codec can't decode byte 0xa7 in position 0: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/src/__pycache__/preprocessing.cpython-311.pyc: 'utf-8' codec can't decode byte 0xa7 in position 0: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/src/__pycache__/augmentation.cpython-311.pyc: 'utf-8' codec can't decode byte 0xa7 in position 0: invalid start byte
# Could not read file /Users/devynmiller/CPSC542_final_project/src/__pycache__/__init__.cpython-311.pyc: 'utf-8' codec can't decode byte 0xa7 in position 0: invalid start byte
# Code contents have been written to code_contents.txt
